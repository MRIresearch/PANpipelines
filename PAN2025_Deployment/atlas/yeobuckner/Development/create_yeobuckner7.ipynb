# %% [markdown]
# ### Create yeobuckner7
# Atlas combines 7-network Yeo Cerebral atlas with the 1-network Buckner Cerebellar atlas. Areas of overlap between cerebellum and cerebrum are resolved by assigning cerebellar values to the overlapping voxels.

# %%
import nibabel as nib
import numpy as np
import pandas as pd

# %%
def reorient(input_file, ori, out_file=None):
    from nipype.interfaces.image import Reorient
    from nipype import Node
    import os

    reorient_node = Node(Reorient(),name="reorient_to_{}".format(ori))
    reorient_node.inputs.in_file =  os.path.abspath(input_file)
    reorient_node.inputs.orientation=ori
    reorient_results = reorient_node.run()
    results_file = os.path.abspath(reorient_results.outputs.out_file)
    if out_file:
        out_file = os.path.abspath(out_file)
        os.system(f"mv {results_file} {out_file}")
    else:
        out_file = results_file
    
    return out_file

# %%
# https://github.com/ThomasYeoLab/CBIG/blob/master/stable_projects/brain_parcellation/Yeo2011_fcMRI_clustering/1000subjects_reference/Yeo_JNeurophysiol11_SplitLabels/Yeo2011_7networks_N1000.split_components.glossary.csv
label_file = "./sources/Originals/Yeo2011_7networks_N1000.split_components.glossary.csv"
yeo_df = pd.read_table(label_file,sep=",")

# %%
yeo_df
# Out:
#                              Label Name                  Network Name  \
# 0                                  NONE                           NaN
# 1                      7Networks_LH_Vis                        visual
# 2                   7Networks_LH_SomMot                   somatomotor
# 3            7Networks_LH_DorsAttn_Post              dorsal attention
# 4             7Networks_LH_DorsAttn_FEF              dorsal attention
# 5            7Networks_LH_DorsAttn_PrCv              dorsal attention
# 6      7Networks_LH_SalVentAttn_ParOper  salience / ventral attention
# 7      7Networks_LH_SalVentAttn_TempOcc  salience / ventral attention
# 8    7Networks_LH_SalVentAttn_FrOperIns  salience / ventral attention
# 9         7Networks_LH_SalVentAttn_PFCl  salience / ventral attention
# 10         7Networks_LH_SalVentAttn_Med  salience / ventral attention
# 11              7Networks_LH_Limbic_OFC                        limbic
# 12         7Networks_LH_Limbic_TempPole                        limbic
# 13                7Networks_LH_Cont_Par                       control
# 14               7Networks_LH_Cont_Temp                       control
# 15               7Networks_LH_Cont_PFCd                       control
# 16               7Networks_LH_Cont_PFCl                       control
# 17                7Networks_LH_Cont_OFC                       control
# 18               7Networks_LH_Cont_PFCv                       control
# 19               7Networks_LH_Cont_pCun                       control
# 20               7Networks_LH_Cont_Cing                       control
# 21              7Networks_LH_Cont_PFCmp                       control
# 22             7Networks_LH_Default_Par                       default
# 23            7Networks_LH_Default_Temp                       default
# 24             7Networks_LH_Default_PFC                       default
# 25         7Networks_LH_Default_pCunPCC                       default
# 26             7Networks_LH_Default_PHC                       default
# 27                     7Networks_RH_Vis                        visual
# 28                  7Networks_RH_SomMot                   somatomotor
# 29           7Networks_RH_DorsAttn_Post              dorsal attention
# 30            7Networks_RH_DorsAttn_FEF              dorsal attention
# 31           7Networks_RH_DorsAttn_PrCv              dorsal attention
# 32  7Networks_RH_SalVentAttn_TempOccPar  salience / ventral attention
# 33         7Networks_RH_SalVentAttn_PrC  salience / ventral attention
# 34   7Networks_RH_SalVentAttn_FrOperIns  salience / ventral attention
# 35        7Networks_RH_SalVentAttn_PFCv  salience / ventral attention
# 36        7Networks_RH_SalVentAttn_PFCl  salience / ventral attention
# 37         7Networks_RH_SalVentAttn_Med  salience / ventral attention
# 38              7Networks_RH_Limbic_OFC                        limbic
# 39         7Networks_RH_Limbic_TempPole                        limbic
# 40                7Networks_RH_Cont_Par                       control
# 41               7Networks_RH_Cont_Temp                       control
# 42               7Networks_RH_Cont_PFCv                       control
# 43               7Networks_RH_Cont_PFCl                       control
# 44               7Networks_RH_Cont_pCun                       control
# 45               7Networks_RH_Cont_Cing                       control
# 46              7Networks_RH_Cont_PFCmp                       control
# 47             7Networks_RH_Default_Par                       default
# 48            7Networks_RH_Default_Temp                       default
# 49            7Networks_RH_Default_PFCv                       default
# 50        7Networks_RH_Default_PFCdPFCm                       default
# 51         7Networks_RH_Default_pCunPCC                       default
#
#                                   Full component name
# 0                                                 NaN
# 1                                              visual
# 2                                         somatomotor
# 3                                           posterior
# 4                                  frontal eye fields
# 5                                  precentral ventral
# 6                                  parietal operculum
# 7                                  temporal occipital
# 8                            frontal operculum insula
# 9                           lateral prefrontal cortex
# 10                                             medial
# 11                             orbital frontal cortex
# 12                                      temporal pole
# 13                                          parietal
# 14                                           temporal
# 15                           dorsal prefrontal cortex
# 16                          lateral prefrontal cortex
# 17                             orbital frontal cortex
# 18                          ventral prefrontal cortex
# 19                                          precuneus
# 20                                          cingulate
# 21                 medial posterior prefrontal cortex
# 22                                           parietal
# 23                                           temporal
# 24                                  prefrontal cortex
# 25               precuneus posterior cingulate cortex
# 26                             parahippocampal cortex
# 27                                             visual
# 28                                        somatomotor
# 29                                          posterior
# 30                                 frontal eye fields
# 31                                 precentral ventral
# 32                        temporal occipital parietal
# 33                                         precentral
# 34                           frontal operculum insula
# 35                          ventral prefrontal cortex
# 36                          lateral prefrontal cortex
# 37                                             medial
# 38                             orbital frontal cortex
# 39                                      temporal pole
# 40                                           parietal
# 41                                           temporal
# 42                          ventral prefrontal cortex
# 43                          lateral prefrontal cortex
# 44                                          precuneus
# 45                                          cingulate
# 46                 medial posterior prefrontal cortex
# 47                                           parietal
# 48                                           temporal
# 49                          ventral prefrontal cortex
# 50  dorsal prefrontal cortex medial prefrontal cortex
# 51               precuneus posterior cingulate cortex

# %%
# ftp://surfer.nmr.mgh.harvard.edu/pub/data/Yeo_JNeurophysiol11_MNI152.zip
# Yeo2011_7Networks_MNI152_FreeSurferConformed1mm_LiberalMask.nii.gz transformed to FSL LAS Space
atlas_file = "./sources/yeo7_1mm.nii.gz"
atlas_img = nib.load(atlas_file)
atlas_data = atlas_img.get_fdata()

# %%
# https://github.com/ThomasYeoLab/CBIG/tree/master/stable_projects/brain_parcellation/Yeo2011_fcMRI_clustering/1000subjects_reference/Yeo_JNeurophysiol11_SplitLabels/MNI152
# $PWD/Yeo2011_7Networks_N1000.split_components.FSL_MNI152_FreeSurferConformed_1mm.nii.gz transformed to FSL LAS space
split_file = "./sources/yeo7_splitlabel_1mm.nii.gz"
split_img = nib.load(split_file)
split_data = split_img.get_fdata()

# %%
from scipy import stats

for roi in range(1,int(np.max(atlas_data))+1):
    mask=atlas_data == roi
    split_rois=split_data[mask]
    split_rois=split_rois[split_rois != 0]
    modalscore = stats.mode(split_rois)
    labs = yeo_df.iloc[int(modalscore.mode),yeo_df.columns.get_loc("Network Name")]
    print(f"network {roi} has {modalscore.mode}which is {labs}")
# Out:
# network 1 has 27.0which is visual
# network 2 has 2.0which is somatomotor
# network 3 has 29.0which is dorsal attention
# network 4 has 34.0which is salience / ventral attention
# network 5 has 39.0which is limbic
# network 6 has 43.0which is control
# network 7 has 24.0which is default

# %%
label_dict = {"Vis": 1,
            "SomMot":2,            
            "DorsAttn":3,     
            "SalVentAttn":4,     
            "Limbic":5,     
            "Cont":6,  
            "Default":7  
}

# %% [markdown]
# Above confirmed also at https://github.com/ThomasYeoLab/CBIG/blob/master/stable_projects/brain_parcellation/Yeo2011_fcMRI_clustering/1000subjects_reference/7NetworksOrderedNames.csv

# %%
yeo_df
# Out:
#                              Label Name                  Network Name  \
# 0                                  NONE                           NaN
# 1                      7Networks_LH_Vis                        visual
# 2                   7Networks_LH_SomMot                   somatomotor
# 3            7Networks_LH_DorsAttn_Post              dorsal attention
# 4             7Networks_LH_DorsAttn_FEF              dorsal attention
# 5            7Networks_LH_DorsAttn_PrCv              dorsal attention
# 6      7Networks_LH_SalVentAttn_ParOper  salience / ventral attention
# 7      7Networks_LH_SalVentAttn_TempOcc  salience / ventral attention
# 8    7Networks_LH_SalVentAttn_FrOperIns  salience / ventral attention
# 9         7Networks_LH_SalVentAttn_PFCl  salience / ventral attention
# 10         7Networks_LH_SalVentAttn_Med  salience / ventral attention
# 11              7Networks_LH_Limbic_OFC                        limbic
# 12         7Networks_LH_Limbic_TempPole                        limbic
# 13                7Networks_LH_Cont_Par                       control
# 14               7Networks_LH_Cont_Temp                       control
# 15               7Networks_LH_Cont_PFCd                       control
# 16               7Networks_LH_Cont_PFCl                       control
# 17                7Networks_LH_Cont_OFC                       control
# 18               7Networks_LH_Cont_PFCv                       control
# 19               7Networks_LH_Cont_pCun                       control
# 20               7Networks_LH_Cont_Cing                       control
# 21              7Networks_LH_Cont_PFCmp                       control
# 22             7Networks_LH_Default_Par                       default
# 23            7Networks_LH_Default_Temp                       default
# 24             7Networks_LH_Default_PFC                       default
# 25         7Networks_LH_Default_pCunPCC                       default
# 26             7Networks_LH_Default_PHC                       default
# 27                     7Networks_RH_Vis                        visual
# 28                  7Networks_RH_SomMot                   somatomotor
# 29           7Networks_RH_DorsAttn_Post              dorsal attention
# 30            7Networks_RH_DorsAttn_FEF              dorsal attention
# 31           7Networks_RH_DorsAttn_PrCv              dorsal attention
# 32  7Networks_RH_SalVentAttn_TempOccPar  salience / ventral attention
# 33         7Networks_RH_SalVentAttn_PrC  salience / ventral attention
# 34   7Networks_RH_SalVentAttn_FrOperIns  salience / ventral attention
# 35        7Networks_RH_SalVentAttn_PFCv  salience / ventral attention
# 36        7Networks_RH_SalVentAttn_PFCl  salience / ventral attention
# 37         7Networks_RH_SalVentAttn_Med  salience / ventral attention
# 38              7Networks_RH_Limbic_OFC                        limbic
# 39         7Networks_RH_Limbic_TempPole                        limbic
# 40                7Networks_RH_Cont_Par                       control
# 41               7Networks_RH_Cont_Temp                       control
# 42               7Networks_RH_Cont_PFCv                       control
# 43               7Networks_RH_Cont_PFCl                       control
# 44               7Networks_RH_Cont_pCun                       control
# 45               7Networks_RH_Cont_Cing                       control
# 46              7Networks_RH_Cont_PFCmp                       control
# 47             7Networks_RH_Default_Par                       default
# 48            7Networks_RH_Default_Temp                       default
# 49            7Networks_RH_Default_PFCv                       default
# 50        7Networks_RH_Default_PFCdPFCm                       default
# 51         7Networks_RH_Default_pCunPCC                       default
#
#                                   Full component name
# 0                                                 NaN
# 1                                              visual
# 2                                         somatomotor
# 3                                           posterior
# 4                                  frontal eye fields
# 5                                  precentral ventral
# 6                                  parietal operculum
# 7                                  temporal occipital
# 8                            frontal operculum insula
# 9                           lateral prefrontal cortex
# 10                                             medial
# 11                             orbital frontal cortex
# 12                                      temporal pole
# 13                                          parietal
# 14                                           temporal
# 15                           dorsal prefrontal cortex
# 16                          lateral prefrontal cortex
# 17                             orbital frontal cortex
# 18                          ventral prefrontal cortex
# 19                                          precuneus
# 20                                          cingulate
# 21                 medial posterior prefrontal cortex
# 22                                           parietal
# 23                                           temporal
# 24                                  prefrontal cortex
# 25               precuneus posterior cingulate cortex
# 26                             parahippocampal cortex
# 27                                             visual
# 28                                        somatomotor
# 29                                          posterior
# 30                                 frontal eye fields
# 31                                 precentral ventral
# 32                        temporal occipital parietal
# 33                                         precentral
# 34                           frontal operculum insula
# 35                          ventral prefrontal cortex
# 36                          lateral prefrontal cortex
# 37                                             medial
# 38                             orbital frontal cortex
# 39                                      temporal pole
# 40                                           parietal
# 41                                           temporal
# 42                          ventral prefrontal cortex
# 43                          lateral prefrontal cortex
# 44                                          precuneus
# 45                                          cingulate
# 46                 medial posterior prefrontal cortex
# 47                                           parietal
# 48                                           temporal
# 49                          ventral prefrontal cortex
# 50  dorsal prefrontal cortex medial prefrontal cortex
# 51               precuneus posterior cingulate cortex

# %%
yeo7_df=yeo_df.copy()
yeo7_df["net7_num"]=0
yeo7_df["net7_name"]=yeo7_df["Network Name"]

# %%
yeo7_df
# Out:
#                              Label Name                  Network Name  \
# 0                                  NONE                           NaN
# 1                      7Networks_LH_Vis                        visual
# 2                   7Networks_LH_SomMot                   somatomotor
# 3            7Networks_LH_DorsAttn_Post              dorsal attention
# 4             7Networks_LH_DorsAttn_FEF              dorsal attention
# 5            7Networks_LH_DorsAttn_PrCv              dorsal attention
# 6      7Networks_LH_SalVentAttn_ParOper  salience / ventral attention
# 7      7Networks_LH_SalVentAttn_TempOcc  salience / ventral attention
# 8    7Networks_LH_SalVentAttn_FrOperIns  salience / ventral attention
# 9         7Networks_LH_SalVentAttn_PFCl  salience / ventral attention
# 10         7Networks_LH_SalVentAttn_Med  salience / ventral attention
# 11              7Networks_LH_Limbic_OFC                        limbic
# 12         7Networks_LH_Limbic_TempPole                        limbic
# 13                7Networks_LH_Cont_Par                       control
# 14               7Networks_LH_Cont_Temp                       control
# 15               7Networks_LH_Cont_PFCd                       control
# 16               7Networks_LH_Cont_PFCl                       control
# 17                7Networks_LH_Cont_OFC                       control
# 18               7Networks_LH_Cont_PFCv                       control
# 19               7Networks_LH_Cont_pCun                       control
# 20               7Networks_LH_Cont_Cing                       control
# 21              7Networks_LH_Cont_PFCmp                       control
# 22             7Networks_LH_Default_Par                       default
# 23            7Networks_LH_Default_Temp                       default
# 24             7Networks_LH_Default_PFC                       default
# 25         7Networks_LH_Default_pCunPCC                       default
# 26             7Networks_LH_Default_PHC                       default
# 27                     7Networks_RH_Vis                        visual
# 28                  7Networks_RH_SomMot                   somatomotor
# 29           7Networks_RH_DorsAttn_Post              dorsal attention
# 30            7Networks_RH_DorsAttn_FEF              dorsal attention
# 31           7Networks_RH_DorsAttn_PrCv              dorsal attention
# 32  7Networks_RH_SalVentAttn_TempOccPar  salience / ventral attention
# 33         7Networks_RH_SalVentAttn_PrC  salience / ventral attention
# 34   7Networks_RH_SalVentAttn_FrOperIns  salience / ventral attention
# 35        7Networks_RH_SalVentAttn_PFCv  salience / ventral attention
# 36        7Networks_RH_SalVentAttn_PFCl  salience / ventral attention
# 37         7Networks_RH_SalVentAttn_Med  salience / ventral attention
# 38              7Networks_RH_Limbic_OFC                        limbic
# 39         7Networks_RH_Limbic_TempPole                        limbic
# 40                7Networks_RH_Cont_Par                       control
# 41               7Networks_RH_Cont_Temp                       control
# 42               7Networks_RH_Cont_PFCv                       control
# 43               7Networks_RH_Cont_PFCl                       control
# 44               7Networks_RH_Cont_pCun                       control
# 45               7Networks_RH_Cont_Cing                       control
# 46              7Networks_RH_Cont_PFCmp                       control
# 47             7Networks_RH_Default_Par                       default
# 48            7Networks_RH_Default_Temp                       default
# 49            7Networks_RH_Default_PFCv                       default
# 50        7Networks_RH_Default_PFCdPFCm                       default
# 51         7Networks_RH_Default_pCunPCC                       default
#
#                                   Full component name  net7_num  \
# 0                                                 NaN         0
# 1                                              visual         0
# 2                                         somatomotor         0
# 3                                           posterior         0
# 4                                  frontal eye fields         0
# 5                                  precentral ventral         0
# 6                                  parietal operculum         0
# 7                                  temporal occipital         0
# 8                            frontal operculum insula         0
# 9                           lateral prefrontal cortex         0
# 10                                             medial         0
# 11                             orbital frontal cortex         0
# 12                                      temporal pole         0
# 13                                          parietal          0
# 14                                           temporal         0
# 15                           dorsal prefrontal cortex         0
# 16                          lateral prefrontal cortex         0
# 17                             orbital frontal cortex         0
# 18                          ventral prefrontal cortex         0
# 19                                          precuneus         0
# 20                                          cingulate         0
# 21                 medial posterior prefrontal cortex         0
# 22                                           parietal         0
# 23                                           temporal         0
# 24                                  prefrontal cortex         0
# 25               precuneus posterior cingulate cortex         0
# 26                             parahippocampal cortex         0
# 27                                             visual         0
# 28                                        somatomotor         0
# 29                                          posterior         0
# 30                                 frontal eye fields         0
# 31                                 precentral ventral         0
# 32                        temporal occipital parietal         0
# 33                                         precentral         0
# 34                           frontal operculum insula         0
# 35                          ventral prefrontal cortex         0
# 36                          lateral prefrontal cortex         0
# 37                                             medial         0
# 38                             orbital frontal cortex         0
# 39                                      temporal pole         0
# 40                                           parietal         0
# 41                                           temporal         0
# 42                          ventral prefrontal cortex         0
# 43                          lateral prefrontal cortex         0
# 44                                          precuneus         0
# 45                                          cingulate         0
# 46                 medial posterior prefrontal cortex         0
# 47                                           parietal         0
# 48                                           temporal         0
# 49                          ventral prefrontal cortex         0
# 50  dorsal prefrontal cortex medial prefrontal cortex         0
# 51               precuneus posterior cingulate cortex         0
#
#                        net7_name
# 0                            NaN
# 1                         visual
# 2                    somatomotor
# 3               dorsal attention
# 4               dorsal attention
# 5               dorsal attention
# 6   salience / ventral attention
# 7   salience / ventral attention
# 8   salience / ventral attention
# 9   salience / ventral attention
# 10  salience / ventral attention
# 11                        limbic
# 12                        limbic
# 13                       control
# 14                       control
# 15                       control
# 16                       control
# 17                       control
# 18                       control
# 19                       control
# 20                       control
# 21                       control
# 22                       default
# 23                       default
# 24                       default
# 25                       default
# 26                       default
# 27                        visual
# 28                   somatomotor
# 29              dorsal attention
# 30              dorsal attention
# 31              dorsal attention
# 32  salience / ventral attention
# 33  salience / ventral attention
# 34  salience / ventral attention
# 35  salience / ventral attention
# 36  salience / ventral attention
# 37  salience / ventral attention
# 38                        limbic
# 39                        limbic
# 40                       control
# 41                       control
# 42                       control
# 43                       control
# 44                       control
# 45                       control
# 46                       control
# 47                       default
# 48                       default
# 49                       default
# 50                       default
# 51                       default

# %%
replacement_dict = {"visual": "Vis",
            "somatomotor": "SomMot",           
            "dorsal attention": "DorsAttn",     
            "ventral attention": "SalVentAttn",     
            "limbic": "Limbic",     
            "control": "Cont",     
            "default": "Default",  
}

# %%
import re
def replace_location(value):
    if not pd.isna(value):
        value = re.sub(r'\s+', ' ', value).strip()
        for key, replacement in replacement_dict.items():
            if key.lower() in value.lower():
                return replacement
    return value

# %%
yeo7_df["net7_name"] = yeo7_df["net7_name"].apply(replace_location)

# %%
yeo7_df["net7_name"].tolist()
# Out:
# [nan,
#  'Vis',
#  'SomMot',
#  'DorsAttn',
#  'DorsAttn',
#  'DorsAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'Limbic',
#  'Limbic',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Default',
#  'Default',
#  'Default',
#  'Default',
#  'Default',
#  'Vis',
#  'SomMot',
#  'DorsAttn',
#  'DorsAttn',
#  'DorsAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'SalventAttn',
#  'Limbic',
#  'Limbic',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Cont',
#  'Default',
#  'Default',
#  'Default',
#  'Default',
#  'Default']

# %%
yeo7_df["net7_num"] = yeo7_df["net7_name"].map(label_dict)

# %%
yeo7_df
# Out:
#                              Label Name                  Network Name  \
# 0                                  NONE                           NaN
# 1                      7Networks_LH_Vis                        visual
# 2                   7Networks_LH_SomMot                   somatomotor
# 3            7Networks_LH_DorsAttn_Post              dorsal attention
# 4             7Networks_LH_DorsAttn_FEF              dorsal attention
# 5            7Networks_LH_DorsAttn_PrCv              dorsal attention
# 6      7Networks_LH_SalVentAttn_ParOper  salience / ventral attention
# 7      7Networks_LH_SalVentAttn_TempOcc  salience / ventral attention
# 8    7Networks_LH_SalVentAttn_FrOperIns  salience / ventral attention
# 9         7Networks_LH_SalVentAttn_PFCl  salience / ventral attention
# 10         7Networks_LH_SalVentAttn_Med  salience / ventral attention
# 11              7Networks_LH_Limbic_OFC                        limbic
# 12         7Networks_LH_Limbic_TempPole                        limbic
# 13                7Networks_LH_Cont_Par                       control
# 14               7Networks_LH_Cont_Temp                       control
# 15               7Networks_LH_Cont_PFCd                       control
# 16               7Networks_LH_Cont_PFCl                       control
# 17                7Networks_LH_Cont_OFC                       control
# 18               7Networks_LH_Cont_PFCv                       control
# 19               7Networks_LH_Cont_pCun                       control
# 20               7Networks_LH_Cont_Cing                       control
# 21              7Networks_LH_Cont_PFCmp                       control
# 22             7Networks_LH_Default_Par                       default
# 23            7Networks_LH_Default_Temp                       default
# 24             7Networks_LH_Default_PFC                       default
# 25         7Networks_LH_Default_pCunPCC                       default
# 26             7Networks_LH_Default_PHC                       default
# 27                     7Networks_RH_Vis                        visual
# 28                  7Networks_RH_SomMot                   somatomotor
# 29           7Networks_RH_DorsAttn_Post              dorsal attention
# 30            7Networks_RH_DorsAttn_FEF              dorsal attention
# 31           7Networks_RH_DorsAttn_PrCv              dorsal attention
# 32  7Networks_RH_SalVentAttn_TempOccPar  salience / ventral attention
# 33         7Networks_RH_SalVentAttn_PrC  salience / ventral attention
# 34   7Networks_RH_SalVentAttn_FrOperIns  salience / ventral attention
# 35        7Networks_RH_SalVentAttn_PFCv  salience / ventral attention
# 36        7Networks_RH_SalVentAttn_PFCl  salience / ventral attention
# 37         7Networks_RH_SalVentAttn_Med  salience / ventral attention
# 38              7Networks_RH_Limbic_OFC                        limbic
# 39         7Networks_RH_Limbic_TempPole                        limbic
# 40                7Networks_RH_Cont_Par                       control
# 41               7Networks_RH_Cont_Temp                       control
# 42               7Networks_RH_Cont_PFCv                       control
# 43               7Networks_RH_Cont_PFCl                       control
# 44               7Networks_RH_Cont_pCun                       control
# 45               7Networks_RH_Cont_Cing                       control
# 46              7Networks_RH_Cont_PFCmp                       control
# 47             7Networks_RH_Default_Par                       default
# 48            7Networks_RH_Default_Temp                       default
# 49            7Networks_RH_Default_PFCv                       default
# 50        7Networks_RH_Default_PFCdPFCm                       default
# 51         7Networks_RH_Default_pCunPCC                       default
#
#                                   Full component name  net7_num    net7_name
# 0                                                 NaN       NaN          NaN
# 1                                              visual       1.0          Vis
# 2                                         somatomotor       2.0       SomMot
# 3                                           posterior       3.0     DorsAttn
# 4                                  frontal eye fields       3.0     DorsAttn
# 5                                  precentral ventral       3.0     DorsAttn
# 6                                  parietal operculum       4.0  SalventAttn
# 7                                  temporal occipital       4.0  SalventAttn
# 8                            frontal operculum insula       4.0  SalventAttn
# 9                           lateral prefrontal cortex       4.0  SalventAttn
# 10                                             medial       4.0  SalventAttn
# 11                             orbital frontal cortex       5.0       Limbic
# 12                                      temporal pole       5.0       Limbic
# 13                                          parietal        6.0         Cont
# 14                                           temporal       6.0         Cont
# 15                           dorsal prefrontal cortex       6.0         Cont
# 16                          lateral prefrontal cortex       6.0         Cont
# 17                             orbital frontal cortex       6.0         Cont
# 18                          ventral prefrontal cortex       6.0         Cont
# 19                                          precuneus       6.0         Cont
# 20                                          cingulate       6.0         Cont
# 21                 medial posterior prefrontal cortex       6.0         Cont
# 22                                           parietal       7.0      Default
# 23                                           temporal       7.0      Default
# 24                                  prefrontal cortex       7.0      Default
# 25               precuneus posterior cingulate cortex       7.0      Default
# 26                             parahippocampal cortex       7.0      Default
# 27                                             visual       1.0          Vis
# 28                                        somatomotor       2.0       SomMot
# 29                                          posterior       3.0     DorsAttn
# 30                                 frontal eye fields       3.0     DorsAttn
# 31                                 precentral ventral       3.0     DorsAttn
# 32                        temporal occipital parietal       4.0  SalventAttn
# 33                                         precentral       4.0  SalventAttn
# 34                           frontal operculum insula       4.0  SalventAttn
# 35                          ventral prefrontal cortex       4.0  SalventAttn
# 36                          lateral prefrontal cortex       4.0  SalventAttn
# 37                                             medial       4.0  SalventAttn
# 38                             orbital frontal cortex       5.0       Limbic
# 39                                      temporal pole       5.0       Limbic
# 40                                           parietal       6.0         Cont
# 41                                           temporal       6.0         Cont
# 42                          ventral prefrontal cortex       6.0         Cont
# 43                          lateral prefrontal cortex       6.0         Cont
# 44                                          precuneus       6.0         Cont
# 45                                          cingulate       6.0         Cont
# 46                 medial posterior prefrontal cortex       6.0         Cont
# 47                                           parietal       7.0      Default
# 48                                           temporal       7.0      Default
# 49                          ventral prefrontal cortex       7.0      Default
# 50  dorsal prefrontal cortex medial prefrontal cortex       7.0      Default
# 51               precuneus posterior cingulate cortex       7.0      Default

# %% [markdown]
# ### Add Cerebellar atlas

# %%
# ftp://surfer.nmr.mgh.harvard.edu/pub/data/Buckner_JNeurophysiol11_MNI152.zip
# Buckner2011_17Networks_MNI152_FreeSurferConformed1mm_LooseMask.nii.gz transformed to FSL LAS Space
buck_file = "./sources/buck7_1mm.nii.gz"
buck_img = nib.load(buck_file)
buck_data = buck_img.get_fdata()

# %% [markdown]
# ### Where do the Yeo and buckner overlap

# %%
mask1=atlas_data > 0
mask2=buck_data > 0
combined_mask = np.logical_and(mask1,mask2)

# %%
atlas_data[combined_mask]
# Out:
# array([3., 1., 3., ..., 3., 3., 3.])

# %%
stats.mode(buck_data[combined_mask])
# Out:
# ModeResult(mode=4.0, count=1781)

# %%
buck_data[combined_mask]
# Out:
# array([6., 6., 6., ..., 6., 6., 6.])

# %%
yeo_data = atlas_data + buck_data

# %%
yeo_data[combined_mask]=buck_data[combined_mask]
yeo_data[combined_mask]
# Out:
# array([6., 6., 6., ..., 6., 6., 6.])

# %%
np.max(yeo_data)
# Out:
# 7.0

# %%
final_img = nib.Nifti1Image(yeo_data, atlas_img.affine, atlas_img.header)
nib.save(final_img, "./outputs/atlas-yeobuckner7_space-MNI152NLin6Asym_res-01_ori-LAS_dseg.nii.gz")

# %%
net7_labeldf = pd.DataFrame(list(label_dict.keys()),columns=["label"])
net7_labeldf["index"] = net7_labeldf["label"].map(label_dict)
net7_labeldf = net7_labeldf[["index","label"]]
net7_labeldf
# Out:
#    index        label
# 0      1          Vis
# 1      2       SomMot
# 2      3     DorsAttn
# 3      4  SalventAttn
# 4      5       Limbic
# 5      6         Cont
# 6      7      Default

# %%
net7_labeldf.to_csv("./outputs/atlas-yeobuckner7_dseg.tsv",sep="\t",header=True, index=False)

# %%
input_file = "./outputs/atlas-yeobuckner7_space-MNI152NLin6Asym_res-01_ori-LAS_dseg.nii.gz"
out_file="./outputs/atlas-yeobuckner7_space-MNI152NLin6Asym_res-01_dseg.nii.gz"
final = reorient(input_file, "RAS", out_file)
# Out:
# 250215-15:35:37,420 nipype.workflow INFO:
# 	 [Node] Setting-up "reorient_to_RAS" in "/tmp/tmp2gd21w9m/reorient_to_RAS".
# 250215-15:35:37,422 nipype.workflow INFO:
# 	 [Node] Executing "reorient_to_RAS" <nipype.interfaces.image.Reorient>
# 250215-15:35:37,626 nipype.workflow INFO:
# 	 [Node] Finished "reorient_to_RAS", elapsed time 0.200254s.

# %%
final
# Out:
# '/groups/ryant/PANapps/PANpipelines/PAN2025_Deployment/atlas/yeobuckner/Development/outputs/atlas-yeobuckner7_space-MNI152NLin6Asym_res-01_dseg.nii.gz'
